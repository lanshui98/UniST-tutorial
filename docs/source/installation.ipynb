# %% [markdown]
# ## Installation

# %%
# !pip install -U git+https://github.com/lanshui98/UniST.git
# Out:
# ...
#   Cloning https://github.com/lanshui98/UniST.git to /tmp/pip-req-build-io83rdn5
#   Running command git clone --filter=blob:none --quiet https://github.com/lanshui98/UniST.git /tmp/pip-req-build-io83rdn5
#   Resolved https://github.com/lanshui98/UniST.git to commit 559193ad2e6125aaaff4361bcdf5f7a3e3a0fb82
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.6/176.6 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.7/447.7 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 45.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.7/180.7 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 2.9 MB/s eta 0:00:00
# ...

# %%
import unist
print(unist.__version__)
# Out:
# 0.1.0

# %%
from unist.metrics import dice_coefficient
from unist.downstream.morph import dilation, erosion
print("✅ Installation successful!")
# Out:
# ✅ Installation successful!
